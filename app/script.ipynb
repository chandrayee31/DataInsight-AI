# %%
import pandas as pd
from services.analysis_service import load_and_validate_csv, generate_basic_summary
from services.prompt_service import build_insight_prompt

# %%
df=pd.read_csv("../data/sample/ecommerce_sales_sample.csv", encoding="latin1")
df.head()
df.columns
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df = load_and_validate_csv("../data/sample/ecommerce_sales_sample.csv")
print(df.head())
print(df["Order Date"].dtypes)
print(df.shape)
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]
# datetime64[ns]
# (9994, 21)

# %%
summary={}
summary["top_region_sales"] = df.groupby("Region")["Sales"].sum().sort_values(ascending=False).head(3).to_dict()
print(summary)
# Out:
# {'top_region_sales': {'West': 725457.8245, 'East': 678781.24, 'Central': 501239.8908}}

# %%
summary=generate_basic_summary(df)
print(summary)
# Out:
# {'total_rows': 9994, 'total_columns': 21, 'total_sales': 2297200.8603000003, 'total_profit': 286397.0217, 'total_quantity': 37873, 'top_region_sales': {'West': 725457.8245, 'East': 678781.24, 'Central': 501239.8908}, 'top_category_sales': {'Technology': 836154.033, 'Furniture': 741999.7953, 'Office Supplies': 719047.032}, 'profit_by_category': {'Furniture': 18451.2728, 'Office Supplies': 122490.8008, 'Technology': 145454.9481}}

# %%
prompt = build_insight_prompt(summary)
print(prompt)
# Out:
# You are a business data analyst.
#
# Analyze the following dataset summary and produce a clear, business-friendly report.
#
# Dataset Summary:
# - Total rows: 9994
# - Total columns: 21
# - Total sales: 2297200.86
# - Total profit: 286397.02
# - Total quantity sold: 37873
#
# Top 3 regions by sales:
# {'West': 725457.8245, 'East': 678781.24, 'Central': 501239.8908}
#
# Category-wise sales:
# {'Technology': 836154.033, 'Furniture': 741999.7953, 'Office Supplies': 719047.032}
#
# Category-wise profit:
# {'Furniture': 18451.2728, 'Office Supplies': 122490.8008, 'Technology': 145454.9481}
#
# Please provide the output in exactly these sections:
# 1. Executive Summary
# 2. Key Observations
# 3. Business Risks or Anomalies
# 4. Recommendations
#
# Keep the language concise, professional, and easy for business stakeholders to understand.
# Do not invent facts outside the provided summary.

# %%
from services.llm_service import generate_insights

insights = generate_insights(prompt)

print(insights)
# Out:
# /Users/chandrayeekumar/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# **Report: Sales and Profit Analysis**
#
# **1. Executive Summary**
#
# Our analysis of the dataset reveals a strong performance across all regions, with the West, East, and Central regions contributing significantly to total sales. The Technology, Furniture, and Office Supplies categories also demonstrate robust sales and profit margins. Overall, the company's total sales and profit have exceeded expectations.
#
# **2. Key Observations**
#
# * The West region accounted for the largest share of total sales, with a contribution of 725,457.82.
# * Technology was the top-selling category, generating 836,154.03 in sales.
# * Office Supplies was the second-highest profitable category, with a profit of 122,490.80.
# * The total quantity sold was 37,873 units.
# * Total sales and profit exceeded expectations, with total sales reaching 2,297,200.86 and total profit standing at 286,397.02.
#
# **3. Business Risks or Anomalies**
#
# * While the overall performance is strong, the Central region lagged behind in terms of sales, generating 501,239.89.
# * The Office Supplies category had the highest profit margin, indicating a potential opportunity for growth and expansion.
# * The relatively low profit margin in the Technology category (145,454.95) may warrant closer examination and potential adjustments to pricing or product mix.
#
# **4. Recommendations**
#
# * Continue to focus on the West region, which has demonstrated strong sales performance.
# * Leverage the success of the Technology category by exploring opportunities for product expansion and diversification.
# * Consider adjusting pricing or product mix in the Technology category to improve profit margins.
# * Analyze the Central region's performance to identify areas for improvement and potential opportunities for growth.
# * Monitor the Office Supplies category's profit margin and explore opportunities for further growth and expansion.
